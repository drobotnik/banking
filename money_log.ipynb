# %%
import pandas as pd

# %%
df = pd.read_excel('14.12 - 15.12 - RBS.xlsx')

# %%
df.head()
# Out:
#         Date  Type                                        Description   Value  \
# 0        NaT   NaN                                                NaN     NaN
# 1 2014-12-09   POS  '2874 08DEC14 , BLK*RAINFOREST , TRUST , 80045...   -4.22
# 2 2014-12-09   POS         '2874 08DEC14 , SCIENCE MUSEUM , LONDON GB -111.49
# 3 2014-12-09   POS          '2874 07DEC14 , COSTCUTTER , LONDON E3 GB  -19.95
# 4 2014-12-09   POS   '2874 08DEC14 , GOOGLE *MUSIC , GOOGLE.COM/CH GB   -9.99
#
#     Balance  Account Name    Account Number
# 0       NaN           NaN               NaN
# 1    985.60      'Current  '162632-10651269
# 2    874.11      'Current  '162632-10651269
# 3    854.16      'Current  '162632-10651269
# 4    844.17      'Current  '162632-10651269

# %%
def parse_bank_description(desc):
    return desk

# %%
df.columns.values
# Out:
# array(['Date', ' Type', ' Description', ' Value', ' Balance',
#        ' Account Name', ' Account Number'], dtype=object)

# %%
df[df[' Value'] > 0]
# Out:
#           Date  Type                                        Description  \
# 6   2014-12-10   BAC  'S YOUSIF , FP 10/12/14 1700 , 400000000151941165
# 12  2014-12-12   BAC                                'HANUMAN PARTNERS L
# 26  2014-12-22   BAC  'ABAZA KHALED , KHALED-RBS , FP 19/12/14 2044 ...
# 120 2015-01-23   BAC  'ABAZA KHALED , KHALED-RBS , FP 23/01/15 1532 ...
# 171 2015-02-12   NaN                                 '160109 12FEB 1439
# 179 2015-02-16   IBP                  '2874 11FEB15 , WWW.HANDYBOOK.COM
# 197 2015-02-23   BAC                                    'FCL CLIENT ACC
# 200 2015-02-25   BAC                                    'FCL CLIENT ACC
# 210 2015-03-09   BAC  'ABAZA KHALED , KHALED-RBS , FP 08/03/15 1752 ...
# 228 2015-03-18   BAC  'S YOUSIF , FP 18/03/15 1040 , 600000000167389384
# 234 2015-03-27   NaN                                 '160053 27MAR 1326
# 241 2015-04-07   C/R                                            '160053
# ...
