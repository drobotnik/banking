# %%
import pandas as pd
import numpy as np

df = pd.DataFrame.from_csv('default_report_2.csv', index_col=False)
df['Date'] = pd.to_datetime(df['Date'], dayfirst=True)
rbs_c = pd.DataFrame.from_csv('raw_test.csv', index_col=False)
rbs_c['Date'] = pd.to_datetime(rbs_c['Date'], dayfirst=True)
fixed_names = (name.strip() for name in rbs_c.columns)
rbs_c.rename(columns=dict(zip(rbs_c.columns, fixed_names)), inplace=True)

# %%
def search_by_val_and_date(bank, value_range, since_date):
    match_value = (bank['Value'] < max(value_range)) & (bank['Value'] > min(value_range))
    match_date = (bank['Date'] > pd.to_datetime(since_date, dayfirst=True))
    return bank[match_value & match_date]

# %%
def unique_strat(budget_row_index, budget_date, budget_amount, bank):
    """
    Checks an entry in the budget logs and sees if there is a 1:1 match with an entry in bank
    That entry in bank has to be 'unmatched'
    """
    date_match = abs(bank['Date'] - budget_date) < pd.Timedelta('4 Days')
    amount_match = bank['Value'] == budget_amount
    uncategorised = bank['Category'].notnull()  # likely to break if not using existing SOT
    matches = bank[date_match & amount_match]
    if len(matches) == 1:
        return (budget_row_index, matches.index[0])
    return False

def reconcile(budget, bank, budget_account='Rbs'):
    """
    Matches entries in budget with entries in RBS
    """
    matched_list = []
    unmatched_list = []
    for n, (date, cat, subcat, amount, acc, payee, note) in budget.iterrows():
        if acc != budget_account:
            pass
        unique_row = unique_strat(n, date, amount, bank)
        if unique_row:
            matched_list += [unique_row]
        else:
            unmatched_list += [n]
    return matched_list, unmatched_list

matched, unmatched = reconcile(df, rbs_c)

# %%
budget_matches, bank_matches = zip(*matched)
budget_matches
# Out:
# (1, 2, 3, 7, 8, 10, 11, 13, 16)

# %%
rbs_period = rbs_c[rbs_c['Date'] > pd.to_datetime('2015/12/09')]
matched_budget_rows = df.iloc[list(budget_matches)]
unmatched_budget_rows = df.iloc[unmatched]
matched_budget_rows.index = bank_matches
matched_bank_rows = pd.concat([rbs_period, matched_budget_rows], axis=1)

# %%
matched_bank_rows[matched_bank_rows['Category'].isnull()]
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Date</th>
#       <th>Type</th>
#       <th>Description</th>
#       <th>Value</th>
#       <th>Balance</th>
#       <th>Account Name</th>
#       <th>Account Number</th>
#       <th>Date</th>
#       <th>Category</th>
#       <th>SubCategory</th>
#       <th>Expense Amount</th>
#       <th>Account</th>
#       <th>Payee</th>
#       <th>Notes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>248</th>
#       <td>2015-12-10</td>
#       <td>POS</td>
#       <td>'9285 09DEC15 C , SUBWAY , CITY ROAD LON GB</td>
#       <td>-6.98</td>
#       <td>2163.01</td>
#       <td>'Current</td>
#       <td>'162632-10651269</td>
#       <td>NaT</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>249</th>
#       <td>2015-12-14</td>
#       <td>POS</td>
#       <td>'9285 11DEC15 , GIVEWELL , 6462332035 US , USD...</td>
#       <td>-4.31</td>
#       <td>2158.70</td>
#       <td>'Current</td>
#       <td>'162632-10651269</td>
#       <td>NaT</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>250</th>
#       <td>2015-12-14</td>
#       <td>POS</td>
#       <td>'9285 11DEC15 , BB *RAINFOREST , TRUST , 80045...</td>
#       <td>-4.31</td>
#       <td>2154.39</td>
#       <td>'Current</td>
#       <td>'162632-10651269</td>
#       <td>NaT</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>251</th>
#       <td>2015-12-14</td>
#       <td>POS</td>
#       <td>'9285 13DEC15 , 447581427540 , FEE GB</td>
#       <td>-20.17</td>
#       <td>2134.22</td>
#       <td>'Current</td>
#       <td>'162632-10651269</td>
#       <td>NaT</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>252</th>
#       <td>2015-12-14</td>
#       <td>POS</td>
#       <td>'9285 12DEC15 C , TFL.GOV.UK/CP , TFL TRAVEL C...</td>
#       <td>-1.50</td>
#       <td>2132.72</td>
#       <td>'Current</td>
#       <td>'162632-10651269</td>
#       <td>NaT</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>253</th>
#       <td>2015-12-14</td>
#       <td>POS</td>
#       <td>'9285 12DEC15 C , PAPERCHASE , STRATFORD GB</td>
#       <td>-3.00</td>
#       <td>2129.72</td>
#       <td>'Current</td>
#       <td>'162632-10651269</td>
#       <td>NaT</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>255</th>
#       <td>2015-12-14</td>
#       <td>POS</td>
#       <td>'9285 12DEC15 C , M AND S SIMPLY FOOD - , SSP ...</td>
#       <td>-8.25</td>
#       <td>2112.89</td>
#       <td>'Current</td>
#       <td>'162632-10651269</td>
#       <td>NaT</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>260</th>
#       <td>2015-12-14</td>
#       <td>POS</td>
#       <td>'9285 12DEC15 C , CO-OP GROUP PETROL, BOW ROAD GB</td>
#       <td>-7.90</td>
#       <td>2066.13</td>
#       <td>'Current</td>
#       <td>'162632-10651269</td>
#       <td>NaT</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>261</th>
#       <td>2015-12-14</td>
#       <td>POS</td>
#       <td>'9285 11DEC15 C , SIMPLY FRESH , LONDON GB</td>
#       <td>-12.47</td>
#       <td>2053.66</td>
#       <td>'Current</td>
#       <td>'162632-10651269</td>
#       <td>NaT</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>264</th>
#       <td>2015-12-15</td>
#       <td>POS</td>
#       <td>'9285 14DEC15 C , SUBWAY , CITY ROAD LON GB</td>
#       <td>-5.50</td>
#       <td>4996.15</td>
#       <td>'Current</td>
#       <td>'162632-10651269</td>
#       <td>NaT</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>265</th>
#       <td>2015-12-15</td>
#       <td>POS</td>
#       <td>'9285 14DEC15 , HACHE BURGER , CONNOISSE , LON...</td>
#       <td>-72.69</td>
#       <td>4923.46</td>
#       <td>'Current</td>
#       <td>'162632-10651269</td>
#       <td>NaT</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>267</th>
#       <td>2015-12-15</td>
#       <td>D/D</td>
#       <td>'OXFAM DD</td>
#       <td>-3.00</td>
#       <td>4850.48</td>
#       <td>'Current</td>
#       <td>'162632-10651269</td>
#       <td>NaT</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>269</th>
#       <td>2015-12-18</td>
#       <td>D/D</td>
#       <td>'OVO ENERGY</td>
#       <td>-44.00</td>
#       <td>4798.98</td>
#       <td>'Current</td>
#       <td>'162632-10651269</td>
#       <td>NaT</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
matched_bank_rows[matched_bank_rows['Category'].notnull()]
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Date</th>
#       <th>Type</th>
#       <th>Description</th>
#       <th>Value</th>
#       <th>Balance</th>
#       <th>Account Name</th>
#       <th>Account Number</th>
#       <th>Date</th>
#       <th>Category</th>
#       <th>SubCategory</th>
#       <th>Expense Amount</th>
#       <th>Account</th>
#       <th>Payee</th>
#       <th>Notes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>254</th>
#       <td>2015-12-14</td>
#       <td>POS</td>
#       <td>'9285 13DEC15 C , CO-OP GROUP PETROL, BOW ROAD GB</td>
#       <td>-8.58</td>
#       <td>2121.14</td>
#       <td>'Current</td>
#       <td>'162632-10651269</td>
#       <td>2015-12-13</td>
#       <td>Food/Groceries</td>
#       <td>Groceries</td>
#       <td>-8.58</td>
#       <td>Rbs</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>256</th>
#       <td>2015-12-14</td>
#       <td>POS</td>
#       <td>'9285 12DEC15 , NEWSPOINT , (STRATFORD) , LOND...</td>
#       <td>-5.17</td>
#       <td>2107.72</td>
#       <td>'Current</td>
#       <td>'162632-10651269</td>
#       <td>2015-12-12</td>
#       <td>Food/Groceries</td>
#       <td>Snack / Sweets</td>
#       <td>-5.17</td>
#       <td>Rbs</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>257</th>
#       <td>2015-12-14</td>
#       <td>POS</td>
#       <td>'9285 12DEC15 C , TORTILLA WESTFIELD, STR , LO...</td>
#       <td>-16.70</td>
#       <td>2091.02</td>
#       <td>'Current</td>
#       <td>'162632-10651269</td>
#       <td>2015-12-12</td>
#       <td>Food/Groceries</td>
#       <td>Restaurant/Fast food</td>
#       <td>-16.70</td>
#       <td>Rbs</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>258</th>
#       <td>2015-12-14</td>
#       <td>POS</td>
#       <td>'9285 12DEC15 C , SACAT MARKS AND , SPENCER , ...</td>
#       <td>-12.00</td>
#       <td>2079.02</td>
#       <td>'Current</td>
#       <td>'162632-10651269</td>
#       <td>2015-12-12</td>
#       <td>Entertainment</td>
#       <td>Night Out</td>
#       <td>-12.00</td>
#       <td>Rbs</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>259</th>
#       <td>2015-12-14</td>
#       <td>POS</td>
#       <td>'9285 12DEC15 , LEGO STORE , STRATFORD CTY GB</td>
#       <td>-4.99</td>
#       <td>2074.03</td>
#       <td>'Current</td>
#       <td>'162632-10651269</td>
#       <td>2015-12-12</td>
#       <td>Misc/One-time</td>
#       <td>Gifts/Charity</td>
#       <td>-4.99</td>
#       <td>Rbs</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>262</th>
#       <td>2015-12-15</td>
#       <td>BAC</td>
#       <td>'ELSEVIER LTD</td>
#       <td>2982.97</td>
#       <td>5036.63</td>
#       <td>'Current</td>
#       <td>'162632-10651269</td>
#       <td>2015-12-16</td>
#       <td>Salary</td>
#       <td>NaN</td>
#       <td>2982.97</td>
#       <td>Rbs</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>263</th>
#       <td>2015-12-15</td>
#       <td>POS</td>
#       <td>'9285 14DEC15 , CURRYS DIGITAL , LONDON GB</td>
#       <td>-34.98</td>
#       <td>5001.65</td>
#       <td>'Current</td>
#       <td>'162632-10651269</td>
#       <td>2015-12-14</td>
#       <td>Departmental</td>
#       <td>Electronics</td>
#       <td>-34.98</td>
#       <td>Rbs</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>266</th>
#       <td>2015-12-15</td>
#       <td>POS</td>
#       <td>'9285 14DEC15 , CYCLE SURGERY , LONDON EC1Y GB</td>
#       <td>-69.98</td>
#       <td>4853.48</td>
#       <td>'Current</td>
#       <td>'162632-10651269</td>
#       <td>2015-12-14</td>
#       <td>Car/Auto</td>
#       <td>Bike</td>
#       <td>-69.98</td>
#       <td>Rbs</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>268</th>
#       <td>2015-12-18</td>
#       <td>IBP</td>
#       <td>'9285 16DEC15 , TESCO STORES-2092</td>
#       <td>-7.50</td>
#       <td>4842.98</td>
#       <td>'Current</td>
#       <td>'162632-10651269</td>
#       <td>2015-12-16</td>
#       <td>Food/Groceries</td>
#       <td>Groceries</td>
#       <td>-7.50</td>
#       <td>Rbs</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
unmatched_budget_rows[unmatched_budget_row]
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Date</th>
#       <th>Category</th>
#       <th>SubCategory</th>
#       <th>Expense Amount</th>
#       <th>Account</th>
#       <th>Payee</th>
#       <th>Notes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2015-12-10</td>
#       <td>Food/Groceries</td>
#       <td>Restaurant/Fast food</td>
#       <td>-10.00</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2015-12-14</td>
#       <td>Food/Groceries</td>
#       <td>Restaurant/Fast food</td>
#       <td>-5.29</td>
#       <td>Rbs</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2015-12-15</td>
#       <td>Food/Groceries</td>
#       <td>Groceries</td>
#       <td>-8.99</td>
#       <td>Cash</td>
#       <td>NaN</td>
#       <td>Coconut Aminos</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>2015-12-15</td>
#       <td>Food/Groceries</td>
#       <td>Restaurant/Fast food</td>
#       <td>-6.15</td>
#       <td>Cash</td>
#       <td>NaN</td>
#       <td>Burrito</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>2015-12-10</td>
#       <td>Entertainment</td>
#       <td>Movies</td>
#       <td>-22.00</td>
#       <td>Rbs</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>2015-12-12</td>
#       <td>Misc/One-time</td>
#       <td>Gifts/Charity</td>
#       <td>-2.00</td>
#       <td>Cash</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>2015-12-12</td>
#       <td>Misc/One-time</td>
#       <td>Misc</td>
#       <td>-3.00</td>
#       <td>Rbs</td>
#       <td>NaN</td>
#       <td>Ribbon</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>2015-12-10</td>
#       <td>Pt</td>
#       <td>NaN</td>
#       <td>40.00</td>
#       <td>Cash</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
matched_step_2 = [()]
